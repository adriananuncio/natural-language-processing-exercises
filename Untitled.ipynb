# %%
# imports
import numpy as np
import pandas as pd

# %% [markdown]
# main menu:
#
# ++ check: if all variables have been answered for the day before
#
#     @ message: 'All documentation for yesterday is complete'
#
# ++ check: if variables are missing answers for the day before
#
#     @ message: 'Please complete yesterday's stats.'
#
# -------------------------------------------------------------------
#
#     * main menu option I
#         - sub menu option I
#             / prompt I
#                 # action (format)
#                 ## second action (format)
#                 ### third action (format)
#             // prompt II
#                 ~ sub sub menu option I
#                     \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#                 ~~ sub sub menu option II
#                      \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#                 ~~~ sub sub menu option III
#                      \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#         - sub menu option II
#             / prompt I
#                 # action (format)
#                 ## second action (format)
#                 ### third action (format)
#             // prompt II
#                 ~ sub sub menu option I
#                     \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#                 ~~ sub sub menu option II
#                      \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#                 ~~~ sub sub menu option III
#                      \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#
#     * main menu option II
#         - sub menu option I
#             / prompt I
#                 ~ sub sub menu option I
#                     \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#                 ~~ sub sub menu option II
#                      \ sub prompt I
#                         # action (format)
#                         ## second action (format)
#                         ### third action (format)
#
#
#           +i check I: check I if statement
#         +e check I: check I
#
#         ++ check II
# ---------------------------------------------------------------
#
#     * Input daily stats
#         "Enter today's date."
#             @ input date (format: 00-00-0000)
#                 # if date does not exist, accept and continue
#                 # else the date exists...
#             -"Is this date correct?"
#                 a. yes, continue to next stat
#                     @ returns next stat to be input documentation
#                 b. no edit date
#                     --" what would you like to edit"
#                         a: edit month
#                         b: edit day
#                         c: edit year
#                         d: delete and re enter date
#                 c. cancel return to main menu
#                     @ returns to main menu
#
#          "Enter today's day of the week"
#              @ input day of the week (format: monday)
#                  # check for correct format
#                  # check input is a day of the week
#              -"Is {day} correct?
#                  a. yes, continue to next stat
#                  b. no edit day
#                  c. return to previous stat
#                  d. cancel return to main menu
#
#         "Enter toaday's weight"
#             @ input weight(format: 000.00 lbs)
#             - "Is this weight correct?"
#                 a. yes, continue to next stat
#                 b. no edit weight
#                 c. return to previous stat
#                 d. cancel return to main menu
#
#         "Enter the hours of sleep from last night"
#             @ action: input hours of sleep (format: 00.00 hours)
#             - "Is {#hours} correct?
#                 a. yes, continue to next stat
#                 b. no edit hours
#                 c. return to previous stat
#                 d. cancel return to main menu
#
# -------------------------------------------------------------------
#         __STATS THAT MAY BE UPDATED THROUGH OUT DAY__
#         - steps
#
#         - water
#             ~ format 000.00 oz
#             ~ verify water is correct
#             ~ edit water
#             ~ next stat
#
#     ---------------------------------------------------------------
#
#     * view history
#
#     ---------------------------------------------------------------
#
#     * medications
#
#         - view medications
#             returns dataframe of medication information
#         - edit medications
#             - add medication
#                 * add medication name
#                     # input medication name
#                 -* add medication dose
#                     # input medication dose
#                 --* add how the medication is supposed to be taken
#                     # add instructions
#                 ---* add medication purpose
#                     # add purpose
#                 ----*add prescribing dr
#                     # add dr
#                 -----* verify information is correct
#                     # correct, save and add another medication
#                         ~ # save and return to main menu
#                     # correct, return to medication menu
#                     # correct
#
#             ~ edit medication
#                 * edit medication name
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit medication dose (make sure dose is only changed for future inputs and does not change previous inputs)
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit medication purpose
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * discontinue medication
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#
#             ~ return to medications menu
#         - return to main menu
#
#     ---------------------------------------------------------------
#
#     * supplements
#         - view supplements
#         - edit supplements
#             ~ add supplements
#             ~ edit supplements
#             ~ remove supplements
#             ~ return to supplements menu
#         - return to main menu
#
#     ---------------------------------------------------------------
#
#     * exit

# %% [markdown]
#     - view medications
#             returns dataframe of medication information
#         - edit medications
#             - add medication
#                 * add medication name
#                     # input medication name
#                 -* add medication dose
#                     # input medication dose
#                 --* add how the medication is supposed to be taken
#                     # add instructions
#                 ---* add medication purpose
#                     # add purpose
#                 ----*add prescribing dr
#                     # add dr
#                 -----* verify information is correct
#                     # correct, save and add another medication
#                         ~ # save and return to main menu
#                     # correct, return to medication menu
#                     # correct
#
#             ~ edit medication
#                 * edit medication name
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit medication dose (make sure dose is only changed for future inputs and does not change previous inputs)
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit medication purpose
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * edit
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#                 * discontinue medication
#                     medication 1
#                     medication 2
#                     medication 3
#                     etc...
#
#             ~ return to medications menu
#         - return to main menu

# %%
def add_medication()
    print('''1. Add a medication
           \n2. Edit a medication
           \n3. Return to main menu
           ''')
    selection = input('Please make a selection: ')
    if selection == '1':
# Out:
# 1. Add a medication
#
# 2. Edit a medication
#
# 3. Return to main menu
